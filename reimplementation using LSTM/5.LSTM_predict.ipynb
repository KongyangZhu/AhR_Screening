# %%
import pandas as pd
import numpy as np
import pickle as pkl
import tensorflow as tf
from keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
dir = r'D:/R/PycharmProjects/interest/Tox2024/Tox_3/data/'
ahr = 'D:/R/PycharmProjects/interest/Tox2024/Tox_3/data/tmp/chemical.csv'
Label_file = dir + 'ahr_MODELS/ahr_label.pkl'
model_file = dir + 'ahr_MODELS/ahr_35x_model_v2.h5'

data = pd.read_csv(ahr)
smiles_data = data['SMILES']
data.head()
# Out:
#            Unnamed: 0                               试剂  \
# 0               磷酸三苯酯             Tri-phenyl phosphate
# 1         磷酸三（2-氯乙基）酯     Tri（2-chloroethyl） phosphate
# 2  2-乙基己基苯基磷酸酯、磷酸二苯辛酯  2-Ethylhexyl diphenyl phosphate
# 3              磷酸三异丁酯            Triisobutyl phosphate
# 4               磷酸三丁酯               Tributyl phosphate
#
#                                           SMILES       AhR        ER  \
# 0  C1=CC=C(C=C1)OP(=O)(OC2=CC=CC=C2)OC3=CC=CC=C3  0.511443  0.475241
# 1                       C(CCl)OP(=O)(OCCCl)OCCCl  0.058784  0.071843
# 2     CCCCC(CC)COP(=O)(OC1=CC=CC=C1)OC2=CC=CC=C2  0.067468  0.077212
# 3                   CC(C)COP(=O)(OCC(C)C)OCC(C)C  0.204924  0.079065
# 4                         CCCCOP(=O)(OCCCC)OCCCC  0.146030  0.557206
#
#          AR     PPARg  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 160  \
# 0  0.022406  0.015818         NaN         NaN         NaN  ...           NaN
# 1  0.032456  0.023627         NaN         NaN         NaN  ...           NaN
# 2  0.136903  0.014266         NaN         NaN         NaN  ...           NaN
# 3  0.026958  0.022545         NaN         NaN         NaN  ...           NaN
# 4  0.039272  0.008876         NaN         NaN         NaN  ...           NaN
#
#    Unnamed: 161  Unnamed: 162  Unnamed: 163  Unnamed: 164  Unnamed: 165  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 166  Unnamed: 167  Unnamed: 168  Unnamed: 169
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN
#
# [5 rows x 170 columns]

# %%
with open(Label_file, 'rb') as f:
    tokenizer = pkl.load(f)

# 数据预处理
max_length = 128
smiles_data = tokenizer.texts_to_sequences(smiles_data)
smiles_data = pad_sequences(smiles_data, maxlen=max_length, padding='post', truncating='post')

# 定义模型参数
vocab_size = len(tokenizer.word_index) + 1

# 将整数序列转换为one-hot编码
x_onehot = np.eye(vocab_size)[smiles_data]

model = load_model(model_file)

# 评估模型
y_pred = model.predict([x_onehot])
# Out:
# 1/1 [==============================] - 0s 245ms/step

# %%
print(y_pred)
# Out:
# [[3.2361573e-01]
#  [4.8011742e-03]
#  [1.3784718e-04]
#  [4.7003833e-04]
#  [7.1896547e-03]
#  [6.2673187e-01]
#  [3.8740365e-03]
#  [2.3120391e-01]
#  [3.2659599e-01]
#  [9.8942971e-01]
#  [1.3532380e-03]
#  [4.0750541e-02]
#  [3.8535439e-03]
#  [4.1869908e-04]
#  [7.8202254e-05]
#  [5.1967107e-04]]
